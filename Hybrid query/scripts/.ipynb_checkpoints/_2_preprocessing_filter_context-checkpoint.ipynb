# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import json
import numpy as np
import pandas as pd
from collections import defaultdict, Counter
#from neo4j import GraphDatabase
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import seaborn as sns

# %%
root_dir = './../data/complimentary_raw_data/raw_catalog_data/athena_pt_samples'
# List to hold all the file paths
file_paths = []

# Walk through the directory structure
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.endswith('.csv') and not filename.startswith('.'):
            # Construct the full file path and add to the list
            file_paths.append(os.path.join(dirpath, filename))
print(f"Total CSV files found: {len(file_paths)}")
# Out:
# Total CSV files found: 166

# %%
df_list = []

# Load each CSV into a DataFrame and append to the list
#This is limited to firest 20 files for complete dataset read the all_data_consolidated.csv file
for file in tqdm(file_paths[0:20]):
    try:
        df = pd.read_csv(file)
        df_list.append(df)
    except Exception as e:
        print(f"Error reading {file}: {e}")

# Concatenate all DataFrames into a single DataFrame if there are any files
if df_list:
    combined_df = pd.concat(df_list, ignore_index=True)
    combined_csv_path = './../data/combined_data.csv'
    combined_df.to_csv(combined_csv_path, index=False)
    print(f"Combined CSV saved at: {combined_csv_path}")
    print(f"Total rows in combined CSV: {combined_df.shape[0]}")
else:
    print("No CSV files found to merge.")
# Out:
# 100%|██████████| 20/20 [00:07<00:00,  2.58it/s]
# Combined CSV saved at: ./../data/combined_data.csv
# Total rows in combined CSV: 175358

# %%
combined_df = pd.read_csv('./../data/combined_data.csv')
combined_df.shape
# Out:
# (175358, 317)

# %%
categories = combined_df['product_type'].unique()

# %%
nan_df = combined_df.groupby('product_type').apply(lambda x: x.isna().sum())
nan_df.head(1)
# Out:
#               asin  active_ingredients  additional_product_information  \
# product_type
# BABY_BOTTLE      0                5098                            5072
#
#               age_range_description  allergen_information  asin.1  \
# product_type
# BABY_BOTTLE                     888                  5089       0
#
#               battery_capacity_unit  battery_capacity_value  \
# product_type
# BABY_BOTTLE                    5098                    5098
#
#               battery_cell_composition  battery_weight_unit  ...  \
# product_type                                                 ...
# BABY_BOTTLE                       5095                 5094  ...
#
#               video_capture_resolution  watch_movement_type  \
# product_type
# BABY_BOTTLE                       5098                 5098
#
#               wireless_communication_technology  zoom_type  shoe_width_unit  \
# product_type
# BABY_BOTTLE                                5098       5098             5098
#
#               shoe_width_value  nut_seed_type  snapshot_day  region_id  \
# product_type
# BABY_BOTTLE               5098           5098             0          0
#
#               marketplace_id
# product_type
# BABY_BOTTLE                0
#
# [1 rows x 317 columns]

# %%
nan_df["total_records"] = combined_df['product_type'].value_counts()

# %%
data = combined_df

# %%
data = data.select_dtypes(exclude=['float64', 'int'])

# %%
data.shape
# Out:
# (175358, 170)

# %%
data.to_csv('./../data/object_data.csv', index = False)

# %%
unique_df = data.groupby('product_type').apply(lambda x: x.nunique())

# %%
unique_df['total_records'] = nan_df['total_records']

# %%
unique_df.columns
# Out:
# Index(['asin', 'active_ingredients', 'additional_product_information',
#        'age_range_description', 'allergen_information', 'asin.1',
#        'battery_capacity_unit', 'battery_cell_composition',
#        'battery_weight_unit', 'binding',
#        ...
#        'shaft_height_value', 'shelf_type', 'sleeve_type', 'stone_shape',
#        'top_style', 'water_resistance_level', 'weave_type',
#        'wireless_provider', 'snapshot_day', 'total_records'],
#       dtype='object', length=171)

# %%
categories = unique_df.index
categories
# Out:
# Index(['BABY_BOTTLE', 'BAKING_MIX', 'BATHWATER_ADDITIVE', 'BATTERY',
#        'BLOOD_PRESSURE_MONITOR', 'BODY_DEODORANT', 'BODY_LUBRICANT', 'BREAD',
#        'BREAKFAST_CEREAL', 'CAKE', 'CANDLE', 'CANDY'],
#       dtype='object', name='product_type')

# %%
unique_df
# Out:
#                         asin  active_ingredients  \
# product_type
# BABY_BOTTLE             4296                   0
# BAKING_MIX              9174                  14
# BATHWATER_ADDITIVE      7385                   9
# BATTERY                 6661                   0
# BLOOD_PRESSURE_MONITOR  2162                   1
# BODY_DEODORANT          7715                  28
# BODY_LUBRICANT          7915                  19
# BREAD                   6698                   3
# BREAKFAST_CEREAL        8655                  20
# CAKE                    8798                   5
# CANDLE                  8164                   0
# CANDY                   9282                   6
#
#                         additional_product_information  age_range_description  \
# product_type
# BABY_BOTTLE                                         25                     57
# BAKING_MIX                                         165                     10
# BATHWATER_ADDITIVE                                  16                     14
# BATTERY                                              2                      5
# BLOOD_PRESSURE_MONITOR                               0                      3
# BODY_DEODORANT                                     141                      4
# BODY_LUBRICANT                                      24                     12
# BREAD                                              194                      6
# BREAKFAST_CEREAL                                   174                     19
# CAKE                                                47                      5
# CANDLE                                               6                     22
# CANDY                                               39                     14
#
#                         allergen_information  asin.1  battery_capacity_unit  \
# product_type
# BABY_BOTTLE                                6    4296                      0
# BAKING_MIX                                42    9174                      0
# BATHWATER_ADDITIVE                         5    7385                      0
# BATTERY                                    0    6661                      6
# BLOOD_PRESSURE_MONITOR                     1    2162                      0
# BODY_DEODORANT                             1    7715                      0
# BODY_LUBRICANT                             7    7915                      1
# BREAD                                     33    6698                      1
# BREAKFAST_CEREAL                          38    8655                      1
# CAKE                                      33    8798                      0
# CANDLE                                     4    8164                      0
# CANDY                                     37    9282                      0
#
#                         battery_cell_composition  battery_weight_unit  \
# product_type
# BABY_BOTTLE                                    3                    2
# BAKING_MIX                                     0                    0
# BATHWATER_ADDITIVE                             1                    1
# BATTERY                                       23                    4
# BLOOD_PRESSURE_MONITOR                        11                    4
# BODY_DEODORANT                                20                    7
# BODY_LUBRICANT                                 3                    2
# BREAD                                          0                    0
# BREAKFAST_CEREAL                               1                    0
# CAKE                                           0                    1
# CANDLE                                         9                    2
# CANDY                                          1                    1
#
#                         binding  ...  shaft_height_value  shelf_type  \
# product_type                     ...
# BABY_BOTTLE                  18  ...                   0           0
# BAKING_MIX                   14  ...                   0           0
# BATHWATER_ADDITIVE           19  ...                   0           0
# BATTERY                      25  ...                   0           0
# BLOOD_PRESSURE_MONITOR       25  ...                   0           0
# BODY_DEODORANT               17  ...                   0           0
# BODY_LUBRICANT               20  ...                   0           0
# BREAD                        12  ...                   0           0
# BREAKFAST_CEREAL             16  ...                   0           0
# CAKE                         12  ...                   0           0
# CANDLE                       22  ...                   1           2
# CANDY                        18  ...                   1           0
#
#                         sleeve_type  stone_shape  top_style  \
# product_type
# BABY_BOTTLE                       0            0          0
# BAKING_MIX                        0            0          0
# BATHWATER_ADDITIVE                4            0          4
# BATTERY                           0            2          0
# BLOOD_PRESSURE_MONITOR            0            0          0
# BODY_DEODORANT                    1            0          0
# BODY_LUBRICANT                    1            0          1
# BREAD                             3            0          0
# BREAKFAST_CEREAL                  1            0          0
# CAKE                              4            0          0
# CANDLE                            6            0          3
# CANDY                             1            0          0
#
#                         water_resistance_level  weave_type  wireless_provider  \
# product_type
# BABY_BOTTLE                                  1           0                  0
# BAKING_MIX                                   0           0                  0
# BATHWATER_ADDITIVE                           3           0                  0
# BATTERY                                      3           0                  0
# BLOOD_PRESSURE_MONITOR                       2           0                  1
# BODY_DEODORANT                               1           0                  0
# BODY_LUBRICANT                               1           0                  0
# BREAD                                        0           0                  0
# BREAKFAST_CEREAL                             1           1                  0
# CAKE                                         0           0                  0
# CANDLE                                       2           1                  0
# CANDY                                        2           0                  0
#
#                         snapshot_day  total_records
# product_type
# BABY_BOTTLE                        1           5098
# BAKING_MIX                         1          10000
# BATHWATER_ADDITIVE                 1          10000
# BATTERY                            1          20000
# BLOOD_PRESSURE_MONITOR             1           6408
# BODY_DEODORANT                     1          20000
# BODY_LUBRICANT                     1          19776
# BREAD                              1          14870
# BREAKFAST_CEREAL                   1          20000
# CAKE                               1           9206
# CANDLE                             1          20000
# CANDY                              1          20000
#
# [12 rows x 171 columns]

# %%
category_attribute = {}
threshold = .05
for index, row in unique_df.iterrows():
    total_records = row[-1]
    category_attribute[index] = {}
    for column_name, value in row.items():
        if value/total_records < threshold:
            category_attribute[index][column_name] ={}

# %%
unique_df.shape
# Out:
# (12, 171)

# %%
threshold = .5
attributes_set = set()
#drop columns with more than 50% unique values
def get_valid_attributes(row):
    valid_columns = []
    total_records = row['total_records']
    for col in unique_df.columns[:-1]:  # Exclude 'category_total_records'
        if row[col] / total_records < threshold:  # Check for less than 50% unique values
            valid_columns.append(col)
            attributes_set.add(col)
    return valid_columns

# %%
unique_df['attributes'] = unique_df.apply(get_valid_attributes, axis = 1)

# %%
unique_df.columns
# Out:
# Index(['asin', 'active_ingredients', 'additional_product_information',
#        'age_range_description', 'allergen_information', 'asin.1',
#        'battery_capacity_unit', 'battery_cell_composition',
#        'battery_weight_unit', 'binding',
#        ...
#        'shelf_type', 'sleeve_type', 'stone_shape', 'top_style',
#        'water_resistance_level', 'weave_type', 'wireless_provider',
#        'snapshot_day', 'total_records', 'attributes'],
#       dtype='object', length=172)

# %%
len(attributes_set)
# Out:
# 170

# %%
data = data[[x for x in attributes_set]]

# %%
data.shape
# Out:
# (175358, 170)

# %%
nan_df = data.groupby('product_type').apply(lambda x: x.isna().sum())
nan_df
# Out:
#                         shaft_height_unit  browse_node_names  \
# product_type
# BABY_BOTTLE                          5098                  0
# BAKING_MIX                          10000                  0
# BATHWATER_ADDITIVE                  10000                  0
# BATTERY                             20000                  0
# BLOOD_PRESSURE_MONITOR               6408                  0
# BODY_DEODORANT                      20000                  0
# BODY_LUBRICANT                      19776                  0
# BREAD                               14870                  0
# BREAKFAST_CEREAL                    20000                  0
# CAKE                                 9206                  0
# CANDLE                              19996                  0
# CANDY                               19998                  0
#
#                         country_as_labeled  light_source_type  top_material  \
# product_type
# BABY_BOTTLE                           4532               5096          5098
# BAKING_MIX                            9727              10000         10000
# BATHWATER_ADDITIVE                    9472              10000         10000
# BATTERY                              19750              19972         20000
# BLOOD_PRESSURE_MONITOR                6200               6394          6408
# BODY_DEODORANT                       18498              20000         20000
# BODY_LUBRICANT                       18851              19774         19776
# BREAD                                14632              14870         14870
# BREAKFAST_CEREAL                     19432              19996         20000
# CAKE                                  8905               9206          9206
# CANDLE                               18386              19610         19982
# CANDY                                19000              20000         20000
#
#                         identity_package_type  additional_product_information  \
# product_type
# BABY_BOTTLE                              5092                            5072
# BAKING_MIX                               9979                            9822
# BATHWATER_ADDITIVE                       9994                            9980
# BATTERY                                 19994                           19994
# BLOOD_PRESSURE_MONITOR                   6400                            6408
# BODY_DEODORANT                          19978                           19660
# BODY_LUBRICANT                          19776                           19724
# BREAD                                   14870                           14340
# BREAKFAST_CEREAL                        19922                           19596
# CAKE                                     9205                            9143
# CANDLE                                  20000                           19970
# CANDY                                   19916                           19912
#
#                         leg_style  pocket_description  title  ...  \
# product_type                                                  ...
# BABY_BOTTLE                  5098                5098      0  ...
# BAKING_MIX                  10000               10000      2  ...
# BATHWATER_ADDITIVE          10000                9998      0  ...
# BATTERY                     20000               20000      0  ...
# BLOOD_PRESSURE_MONITOR       6408                6408      4  ...
# BODY_DEODORANT              19996               20000      0  ...
# BODY_LUBRICANT              19776               19776      0  ...
# BREAD                       14868               14868      0  ...
# BREAKFAST_CEREAL            20000               20000      0  ...
# CAKE                         9206                9206      1  ...
# CANDLE                      19998               19996      0  ...
# CANDY                       20000               20000      2  ...
#
#                         product_types  frame_material  coverage  closure_type  \
# product_type
# BABY_BOTTLE                         0            5096      5096          5082
# BAKING_MIX                          0           10000     10000         10000
# BATHWATER_ADDITIVE                  0           10000      9959          9993
# BATTERY                             0           19996     20000         20000
# BLOOD_PRESSURE_MONITOR              0            6408      6408          6384
# BODY_DEODORANT                      0           19992     19894         19992
# BODY_LUBRICANT                      0           19776     19603         19766
# BREAD                               0           14870     14870         14854
# BREAKFAST_CEREAL                    0           20000     20000         19882
# CAKE                                0            9206      9206          9201
# CANDLE                              0           19958     19982         19946
# CANDY                               0           20000     20000         19996
#
#                         target_audience   upc  battery_weight_unit  \
# product_type
# BABY_BOTTLE                        3275  1491                 5094
# BAKING_MIX                         9984  3504                10000
# BATHWATER_ADDITIVE                 9825  3788                 9995
# BATTERY                           19948  9320                17934
# BLOOD_PRESSURE_MONITOR             6378  3148                 6180
# BODY_DEODORANT                    13074  7018                19844
# BODY_LUBRICANT                    19399  7103                19744
# BREAD                             14854  3162                14870
# BREAKFAST_CEREAL                  19900  6110                20000
# CAKE                               9202  3223                 9205
# CANDLE                            17996  6326                19932
# CANDY                             19928  8196                19998
#
#                         pattern_type  collar_style  sodium_unit
# product_type
# BABY_BOTTLE                     5097          5098         5098
# BAKING_MIX                     10000         10000         9229
# BATHWATER_ADDITIVE              9992         10000         9996
# BATTERY                        20000         19996        20000
# BLOOD_PRESSURE_MONITOR          6408          6408         6408
# BODY_DEODORANT                 19996         20000        20000
# BODY_LUBRICANT                 19774         19776        19776
# BREAD                          14868         14866        12352
# BREAKFAST_CEREAL               19996         20000        17866
# CAKE                            9200          9206         7920
# CANDLE                         19988         19996        20000
# CANDY                          20000         19998        19458
#
# [12 rows x 170 columns]

# %%
nan_df["total_records"] = combined_df['product_type'].value_counts()

# %%
threshold_nan = .9
attributes_set = set()
#drop columns with more than 50% unique values
def get_non_nan_attributes(row):
    valid_columns = []
    total_records = row['total_records']
    for col in nan_df.columns[:-1]:  # Exclude 'category_total_records'
        if row[col] / total_records < threshold:  # Check for less than 50% unique values
            valid_columns.append(col)
            attributes_set.add(col)
    return valid_columns

# %%
nan_df['attributes'] = nan_df.apply(get_non_nan_attributes, axis = 1)

# %%
len(attributes_set)
# Out:
# 43

# %%
print(attributes_set)
# Out:
# {'color', 'size', 'flavor', 'browse_node_names', 'item_package_weight_unit', 'age_range_description', 'weight_unit', 'model_number', 'browse_node_ids', 'shipping_weight_unit', 'unit_count_type', 'scent', 'product_type', 'browse_assignment', 'title', 'asin', 'voltage_unit', 'brand', 'battery_cell_composition', 'snapshot_day', 'item_form', 'description', 'bullet_point', 'asin.1', 'gl_product_group_type', 'manufacturer', 'gl_family', 'item_height_unit', 'winning_images', 'item_type_keyword', 'container_type', 'binding', 'material_type_free', 'product_types', 'part_number', 'item_length_unit', 'material', 'upc', 'shelf_life_unit', 'light_type', 'item_width_unit', 'item_volume_unit', 'thesaurus_subject_keyword'}

# %%
data = data[[x for x in attributes_set]]
data.shape
# Out:
# (175358, 43)

# %%
columns_to_drop = ['gl_product_group_type', 'browse_node_names', 'browse_assignment', 'weight_unit', 'item_type_keyword', 'item_height_unit', 
                   'part_number', 
                  'item_length_unit', 'item_width_unit', 'description', 'model_number', 'snapshot_day', 'size', 'shipping_weight_unit', 'product_types',
                  'item_form', 'item_package_weight_unit', 'thesaurus_subject_keyword', 'upc', 'browse_node_ids', 'gl_family', 'unit_count_type']
cleaned_df = data.drop(columns=columns_to_drop, errors='ignore')

# %%
cleaned_df.shape
# Out:
# (175358, 21)

# %%
attributes_list = cleaned_df.columns
attributes_list
# Out:
# Index(['color', 'flavor', 'age_range_description', 'scent', 'product_type',
#        'title', 'asin', 'voltage_unit', 'brand', 'battery_cell_composition',
#        'bullet_point', 'asin.1', 'manufacturer', 'winning_images',
#        'container_type', 'binding', 'material_type_free', 'material',
#        'shelf_life_unit', 'light_type', 'item_volume_unit'],
#       dtype='object')

# %%
cleaned_df.to_csv('./../data/cleaned__data.csv', index=False)

# %%
combined_df.shape
# Out:
# (175358, 317)

# %%
cleaned_df['color'].unique()
# Out:
# array(['Orange, Yellow, Gray', '["Multi"]', '["Black"]', ...,
#        'Milk Chocolate Caramel', 'Blue, White, Red',
#        'Blue (Pastel) Tower 1.5 lbs'], dtype=object)

# %%
import ast
def normalize_color_entry(entry):
    if pd.isna(entry):
        return ''
    
    # Convert all entries to string
    entry = str(entry)
    
    # Remove entries that start with a digit
    if entry and entry[0].isdigit():
        return ''
    
    # Try to convert JSON-like strings
    try:
        colors = ast.literal_eval(entry)
        if isinstance(colors, list):
            return ', '.join(colors)
    except (ValueError, SyntaxError):
        pass
    
    # Split by common separators
    if ',' in entry:
        colors = [color.strip() for color in entry.split(',')]
        return ', '.join(colors)
    
    return entry

# %%
cleaned_df['color'] = cleaned_df['color'].apply(normalize_color_entry)

# %%
# Remove non-color-related information
color_keywords = ['orange', 'yellow', 'gray', 'multi', 'black', 'blue', 'white', 'red', 'pastel', 'tower', 'lbs']

# %%
def filter_colors(entry):
    colors = [color for color in entry.split(', ') if any(keyword in color.lower() for keyword in color_keywords)]
    return ', '.join(colors)

cleaned_df['filtered_color'] = cleaned_df['color'].apply(filter_colors)

# %%
cleaned_df['color'] = cleaned_df['filtered_color']
cleaned_df = cleaned_df.drop(columns=['filtered_color'])

# %%
cleaned_df.to_csv('./../data/cleaned__data1.csv', index=False)

# %%
def normalize_entry(entry):
    if pd.isna(entry):
        return ''
    
    # Convert all entries to string
    entry = str(entry)
    
    # Remove entries that start with a digit
    if entry and entry[0].isdigit():
        return ''
    
    # Try to convert JSON-like strings
    try:
        parsed_entry = ast.literal_eval(entry)
        if isinstance(parsed_entry, list):
            return ', '.join(map(str, parsed_entry))
    except (ValueError, SyntaxError):
        pass
    
    # Split by common separators if needed (specific to the 'color' column in the example)
    if ',' in entry:
        parts = [part.strip() for part in entry.split(',')]
        return ', '.join(parts)
    
    return entry

# Apply the normalization function to all columns
for column in cleaned_df.columns:
    cleaned_df[column] = cleaned_df[column].apply(normalize_entry)

# %%
cleaned_df.shape
# Out:
# (175358, 21)

# %%
print(combined_df.columns)
# Out:
# Index(['asin', 'active_ingredients', 'additional_product_information',
#        'age_range_description', 'allergen_information', 'asin.1',
#        'battery_capacity_unit', 'battery_capacity_value',
#        'battery_cell_composition', 'battery_weight_unit',
#        ...
#        'video_capture_resolution', 'watch_movement_type',
#        'wireless_communication_technology', 'zoom_type', 'shoe_width_unit',
#        'shoe_width_value', 'nut_seed_type', 'snapshot_day', 'region_id',
#        'marketplace_id'],
#       dtype='object', length=317)

# %%
df = combined_df.select_dtypes(['float64', 'int'])

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# battery_capacity_value 77
# battery_weight_value 272
# capacity_value 125
# carbohydrate_sugars 151
# carbohydrate_total 184
# case_pack_quantity 46
# energy_content 285
# formulation_type 0
# full_cure_time_unit 0
# full_cure_time_value 0
# gtin 8972
# honey_type 0
# is_waterproof 0
# item_diameter_value 29
# item_height 2289
# item_length 2335
# item_package_quantity 125
# item_package_weight_value 5790
# item_volume_value 579
# item_width 2215
# liquid_volume_value 307
# list_price_value 3817
# monounsaturated_fat 18
# num_batteries_quantity 35
# number_of_blades 3
# number_of_items 90
# number_of_pieces 44
# occasion 0
# ply 0
# polyunsaturated_fat 19
# product_grade 0
# protein_value 83
# saturated_fat 172
# serving_quantity 159
# shelf_life_value 816
# shipping_weight_value 5548
# snack_food_bar_type 0
# sodium_value 226
# style_name 0
# total_eaches 55
# total_fat 133
# trans_fat 24
# unable_to_parse 0
# unit_count 2332
# voltage_value 72
# weight_value 3309
# head_style 0
# head_type 0
# gl_name 0
# gl_code 40
# category_code 0
# subcategory_code 0
# glance_view_band 0
# edge_path_names 0
# nail_polish_type 0
# descriptionsource 0
# lens_type 0
# number_of_speeds 0
# seat_material_type 0
# furniture_finish 0
# insole_type 0
# number_of_shelves 0
# number_of_wheels 0
# rise_style 0
# surround_sound_channel_configuration 1
# total_usb_ports 2
# gv 4712
# si 17678
# style 0
# alert_type 0
# back_finding 0
# care_instructions 0
# closure_material 0
# connectivity_protocol 0
# connectivity_technology 0
# control_method 0
# control_type 0
# controller_type 0
# controls_type 0
# deprecated_variation_theme_id 0
# deprecated_variation_theme_name 0
# drain_type 0
# drive_system 0
# engine_type 0
# expected_blooming_period 0
# expected_planting_period 0
# external_testing_certification 0
# fabric_type 0
# fabric_wash 0
# filter_type 0
# fixture_type 0
# focus_type 0
# frame_rate 0
# front_style 0
# fuel_type 0
# has_lid 0
# has_nonstick_coating 0
# heating_element_type 0
# heating_method 0
# height_map 0
# human_interface_input 0
# international_protection_rating 0
# is_assembly_required 0
# is_customizable 0
# is_dishwasher_safe 0
# is_foldable 0
# is_microwaveable 0
# is_oven_safe 0
# is_stain_resistant 0
# item_hardness 0
# item_length_description 0
# item_styling 0
# lifestyle 0
# lock_type 0
# low_light_technology 0
# metal_type 0
# number_of_doors 0
# number_of_drawers 0
# opening_shape 0
# paint_type 0
# paper_finish 0
# pile_height 0
# polarization_type 0
# room_type 0
# seating_capacity 0
# shell_type 0
# signal_format 0
# soil_type 0
# sole_material 0
# specification_met 0
# strap_type 0
# sunlight_exposure 0
# switch_type 0
# toe_style 0
# underwire_type 0
# usda_hardiness_zone 0
# ventilation_type 0
# video_capture_format 0
# video_capture_resolution 0
# watch_movement_type 0
# wireless_communication_technology 0
# zoom_type 0
# shoe_width_unit 0
# shoe_width_value 0
# nut_seed_type 0
# region_id 1
# marketplace_id 1

# %%
selected_df=df[['item_height', 'item_length', 'item_volume_value', 'item_width', 'battery_capacity_value', 'battery_weight_value']]

# %%
cleaned_df = cleaned_df.join(selected_df)

# %%
cleaned_df.shape
# Out:
# (175358, 27)

# %%
cleaned_df.to_csv('./../data/cleaned_data.csv', index = False)

# %%
cleaned_df.shape
# Out:
# (175358, 27)

# %%
# Define the columns to bin
columns_to_bin = [
    'item_height', 'item_length', 'item_volume_value',
    'item_width', 'battery_capacity_value', 'battery_weight_value'
]

# %%
filtered_df = cleaned_df[['product_type','item_height', 'item_length', 'item_volume_value',
    'item_width', 'battery_capacity_value', 'battery_weight_value']]

# %%
filtered_df.head(5)
# Out:
#   product_type  item_height  item_length  item_volume_value  item_width  \
# 0  BABY_BOTTLE          NaN          NaN                NaN         NaN
# 1  BABY_BOTTLE          NaN          NaN                NaN         NaN
# 2  BABY_BOTTLE         9.50        11.00                NaN        4.00
# 3  BABY_BOTTLE         2.38         7.00                NaN        2.38
# 4  BABY_BOTTLE         2.55        10.05                NaN        4.75
#
#    battery_capacity_value  battery_weight_value
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN

# %%
columns_to_aggregate = [
    'item_height', 'item_length', 'item_volume_value',
    'item_width', 'battery_capacity_value', 'battery_weight_value'
]
agg_df = filtered_df.groupby('product_type')[columns_to_aggregate].agg(['min', 'max', 'count'])

# %%
agg_df
# Out:
#                        item_height                    item_length  \
#                                min          max count         min
# product_type
# BABY_BOTTLE                    0.0   235.000000  3038         0.0
# BAKING_MIX                     0.0   448.818897  2606         0.0
# BATHWATER_ADDITIVE             0.0    78.740157  3770         0.0
# BATTERY                        0.0    95.275590  7398         0.0
# BLOOD_PRESSURE_MONITOR         0.0   196.850000  2176         0.0
# BODY_DEODORANT                 0.0   190.000000  8482         0.0
# BODY_LUBRICANT                 0.0   590.550000  7154         0.0
# BREAD                          0.0    96.456693  4790         0.0
# BREAKFAST_CEREAL               0.0   826.770000  7162         0.0
# CAKE                           0.0  1496.060000  1832         0.0
# CANDLE                         0.0    72.000000  9330         0.0
# CANDY                          0.0  1035.431000  5272         0.0
#
#                                           item_volume_value               \
#                                 max count               min          max
# product_type
# BABY_BOTTLE              201.000000  3038             0.000  3030000.000
# BAKING_MIX               413.385826  2606             0.000     1470.000
# BATHWATER_ADDITIVE        70.870000  3770             0.020  6188000.000
# BATTERY                 2685.000000  7398             0.000     4588.000
# BLOOD_PRESSURE_MONITOR   196.850000  2176             0.140   464400.000
# BODY_DEODORANT            45.000000  8482             0.030     2857.000
# BODY_LUBRICANT           590.550000  7154             0.100     3800.000
# BREAD                     24.409449  4790             0.061      226.800
# BREAKFAST_CEREAL         433.070000  7162             0.350      583.000
# CAKE                    9527.540000  1832             0.000    57420.000
# CANDLE                    77.550000  9330             0.000    11496.816
# CANDY                    456.692913  5272             0.350     1000.000
#
#                               item_width                     \
#                         count        min          max count
# product_type
# BABY_BOTTLE               768        0.0   201.000000  3038
# BAKING_MIX                152        0.0   295.275590  2606
# BATHWATER_ADDITIVE       1038        0.0    95.000000  3770
# BATTERY                   196        0.0  1976.771652  7398
# BLOOD_PRESSURE_MONITOR     80        0.0   161.000000  2176
# BODY_DEODORANT          13186        0.0   220.500000  8482
# BODY_LUBRICANT           5598        0.0   590.550000  7154
# BREAD                      74        0.0    96.456693  4790
# BREAKFAST_CEREAL          192        0.0   244.094488  7162
# CAKE                      191        0.0  4566.920000  1832
# CANDLE                    368        0.0    72.000000  9330
# CANDY                      74        0.0   374.015000  5272
#
#                        battery_capacity_value                 \
#                                           min      max count
# product_type
# BABY_BOTTLE                               NaN      NaN     0
# BAKING_MIX                                NaN      NaN     0
# BATHWATER_ADDITIVE                        NaN      NaN     0
# BATTERY                                   1.0  90000.0  6686
# BLOOD_PRESSURE_MONITOR                    NaN      NaN     0
# BODY_DEODORANT                            NaN      NaN     0
# BODY_LUBRICANT                         4400.0   4400.0     2
# BREAD                                  4400.0   4400.0     8
# BREAKFAST_CEREAL                       8800.0   8800.0     6
# CAKE                                      NaN      NaN     0
# CANDLE                                    NaN      NaN     0
# CANDY                                     NaN      NaN     0
#
#                        battery_weight_value
#                                         min      max count
# product_type
# BABY_BOTTLE                            0.00     5.00     4
# BAKING_MIX                              NaN      NaN     0
# BATHWATER_ADDITIVE                     5.40   200.00     5
# BATTERY                                0.00  1200.00  2066
# BLOOD_PRESSURE_MONITOR                 0.00   350.00   228
# BODY_DEODORANT                         0.00     5.00   156
# BODY_LUBRICANT                         0.00    20.00    32
# BREAD                                   NaN      NaN     0
# BREAKFAST_CEREAL                        NaN      NaN     0
# CAKE                                 454.00   454.00     1
# CANDLE                                 0.10   130.00    68
# CANDY                                 18.34    18.34     2

# %%
# Define the columns to bin
columns_to_bin = [
    'item_height', 'item_length', 'item_volume_value',
    'item_width', 'battery_capacity_value', 'battery_weight_value'
]

def bin_columns(group, num_bins=10):
    product_type = group['product_type'].iloc[0]  # Extract product_type
    binned_data = group.copy()
    
    for column in columns_to_bin:
        if group[column].notnull().sum() > 0:  # Check if there are non-null values
            binned_data[column + '_bin'] = pd.cut(
                group[column], 
                bins=num_bins, 
                labels=[f'{product_type}_{i+1}' for i in range(num_bins)],
                duplicates='drop'
            )
            # Add an empty string to the categories to allow replacement
            binned_data[column + '_bin'] = binned_data[column + '_bin'].cat.add_categories([''])
        else:
            binned_data[column + '_bin'] = np.nan
    return binned_data

# Apply the function to each group
binned_df = filtered_df.groupby('product_type').apply(bin_columns).reset_index(drop=True)

# Replace NaN values with empty strings
binned_df = binned_df.fillna('')

binned_df.head(5)
# Out:
#   product_type item_height item_length item_volume_value item_width  \
# 0  BABY_BOTTLE
# 1  BABY_BOTTLE
# 2  BABY_BOTTLE         9.5        11.0                          4.0
# 3  BABY_BOTTLE        2.38         7.0                         2.38
# 4  BABY_BOTTLE        2.55       10.05                         4.75
#
#   battery_capacity_value battery_weight_value item_height_bin item_length_bin  \
# 0
# 1
# 2                                               BABY_BOTTLE_1   BABY_BOTTLE_1
# 3                                               BABY_BOTTLE_1   BABY_BOTTLE_1
# 4                                               BABY_BOTTLE_1   BABY_BOTTLE_1
#
#   item_volume_value_bin item_width_bin battery_capacity_value_bin  \
# 0
# 1
# 2                        BABY_BOTTLE_1
# 3                        BABY_BOTTLE_1
# 4                        BABY_BOTTLE_1
#
#   battery_weight_value_bin
# 0
# 1
# 2
# 3
# 4

# %%
cleaned_df.columns
# Out:
# Index(['color', 'flavor', 'age_range_description', 'scent', 'product_type',
#        'title', 'asin', 'voltage_unit', 'brand', 'battery_cell_composition',
#        'bullet_point', 'asin.1', 'manufacturer', 'winning_images',
#        'container_type', 'binding', 'material_type_free', 'material',
#        'shelf_life_unit', 'light_type', 'item_volume_unit', 'item_height',
#        'item_length', 'item_volume_value', 'item_width',
#        'battery_capacity_value', 'battery_weight_value'],
#       dtype='object')

# %%
binned_df = binned_df.drop(['item_height', 'item_length', 'item_volume_value',
    'item_width', 'battery_capacity_value', 'battery_weight_value', 'product_type'],axis = 1)

# %%
binned_df.shape
# Out:
# (175358, 6)

# %%
merged_df = pd.merge(cleaned_df, binned_df, left_index=True, right_index=True, suffixes=('', '_bin'))

# %%
merged_df.shape
# Out:
# (175358, 33)

# %%
merged_df.head(5)
# Out:
#                   color flavor age_range_description scent product_type  \
# 0  Orange, Yellow, Gray                         Baby        BABY_BOTTLE
# 1                 Multi                          Kid        BABY_BOTTLE
# 2                 Black                                     BABY_BOTTLE
# 3            multicolor                          Kid        BABY_BOTTLE
# 4                                               Baby        BABY_BOTTLE
#
#                                                title        asin voltage_unit  \
# 0  Copco Hydra Reusable Tritan Water Bottle Spill...  B07MZCMZNG
# 1  Nuby Thirsty Kids Push Button Flip-it Soft Spo...  B07T175PWC
# 2  J.L. Childress MaxiCOOL 4 Bottle Breastmilk Co...  B0009RNXNK
# 3  Baby Fanatic NCAA Alabama Crimson Tide Unisex ...  B06XXTX2H2
# 4          Dr. Brown's Pink 8 Ounce Bottles (2 Pack)  B00JLVEJ88
#
#             brand battery_cell_composition  ... item_volume_value item_width  \
# 0           Copco                           ...               NaN        NaN
# 1            Nuby                           ...               NaN        NaN
# 2  J.L. Childress                           ...               NaN       4.00
# 3    Baby Fanatic                           ...               NaN       2.38
# 4     Dr. Brown's                           ...               NaN       4.75
#
#   battery_capacity_value battery_weight_value item_height_bin item_length_bin  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN   BABY_BOTTLE_1   BABY_BOTTLE_1
# 3                    NaN                  NaN   BABY_BOTTLE_1   BABY_BOTTLE_1
# 4                    NaN                  NaN   BABY_BOTTLE_1   BABY_BOTTLE_1
#
#   item_volume_value_bin item_width_bin battery_capacity_value_bin  \
# 0
# 1
# 2                        BABY_BOTTLE_1
# 3                        BABY_BOTTLE_1
# 4                        BABY_BOTTLE_1
#
#   battery_weight_value_bin
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 33 columns]

# %%
merged_df = merged_df.drop(['item_height', 'item_length', 'item_volume_value',
    'item_width', 'battery_capacity_value', 'battery_weight_value'],axis = 1)

# %%
merged_df.shape
# Out:
# (175358, 27)

# %%
merged_df.to_csv('./../data/final_data.csv', index = False)

# %%
category_attribute_frequency = {}
for index, row in merged_df.iterrows():
    category = row['product_type']
    if category not in category_attribute_frequency.keys():
        category_attribute_frequency[category] = {}
    else:
        for col in merged_df.columns:
            if col != 'product_type':
                if col not in category_attribute_frequency[category].keys():
                    category_attribute_frequency[category][col] = {}
                else:
                    value = str(row[col]).lower()
                    if value == '':
                        continue
                    if value not in category_attribute_frequency[category][col].keys():
                        category_attribute_frequency[category][col][value] = 1
                    else:
                        category_attribute_frequency[category][col][value] += 1

# %%
with open('./../data/category_attribute_frequency.json', 'w') as json_file:
    json.dump(category_attribute_frequency, json_file, indent=4)
